# %% [markdown]
# <a href="https://colab.research.google.com/github/GermanMay14/Own-scripts/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Referencia https://gist.github.com/CarlosRabago/6f2a1dff6e7d44e39c18c6787a0a2e31
# le agregué que saque números y pongo todo en minúsculas
# !pip install WordCloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import re

# %%
import matplotlib.pyplot as plt
def draw_wordcloud(wordcloud, size):
    plt.figure(figsize = size)
    plt.imshow(wordcloud) 
    plt.axis("off")

# %%
# seleccionar el documento completo (no importa que tenga tablas, gráficos, etc) y pegar entre las comillas triples
text = """ Texto acá """

# %%
# saco números y paso a minúsculas
text = re.sub("([0-9])", "",text)
text = text.lower()

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
from wordcloud import WordCloud 
stopwords = set(stopwords.words('spanish', 'english')) 
# acá se pueden agregar a mano otros Stopwords
stopwords.update([ "chingo", "xq","aaay","Jajajaa","perra","kieren","verga","inés", "si", "SI", "llegar","pngkit", "pongo","vuelve", "llegara"])
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

def plot_cloud(wordcloud):
    # Se establece el tamaño de la imagen
    plt.figure(figsize=(20, 15))
    # Mostrar la imagen
    plt.imshow(wordcloud) 
    # Eje sin detalles
    plt.axis("off");

# Generar nube de palabras
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='grey', colormap=paletaColores, collocations=False, stopwords = stopwords).generate(text)
# Impresion
plot_cloud(wordcloud)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
